# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# ## Load and edit data

# %% [markdown]
# ### Load and edit meta data

# %%
meta_df_1 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_131_AMBR_meta_data_export.csv')

# %%
meta_df_1
# Out:
#                          Parent Culture Base Medium Container ID (calculated)  \
# 0   DDB_PD_131_AMBR_DDB35-006_R05_Main_  DDB_BM_016                       R05
# 1   DDB_PD_131_AMBR_DDB35-006_R06_Main_  DDB_BM_016                       R06
# 2   DDB_PD_131_AMBR_DDB35-006_R07_Main_  DDB_BM_016                       R07
# 3   DDB_PD_131_AMBR_DDB35-006_R08_Main_  DDB_BM_016                       R08
# 4   DDB_PD_131_AMBR_DDB35-006_R09_Main_  DDB_BM_016                       R09
# 5   DDB_PD_131_AMBR_DDB35-006_R10_Main_  DDB_BM_016                       R10
# 6   DDB_PD_131_AMBR_DDB35-006_R11_Main_  DDB_BM_016                       R11
# 7   DDB_PD_131_AMBR_DDB35-006_R12_Main_  DDB_BM_016                       R12
# 8   DDB_PD_131_AMBR_DDB35-006_R13_Main_  DDB_BM_016                       R13
# 9   DDB_PD_131_AMBR_DDB35-006_R14_Main_  DDB_BM_016                       R14
# 10  DDB_PD_131_AMBR_DDB35-006_R15_Main_  DDB_BM_016                       R15
# 11  DDB_PD_131_AMBR_DDB35-006_R16_Main_  DDB_BM_016                       R16
#
#    Container Type Control? Culture Type       Experiment Feed Medium #1  \
# 0        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 1        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 2        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 3        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 4        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 5        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 6        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 7        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 8        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 9        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 10       AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 11       AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
#
#    Reactor/Plate/Flask Number  Replicate #  \
# 0                         R05            1
# 1                         R06            2
# 2                         R07            3
# 3                         R08            1
# 4                         R09            2
# 5                         R10            3
# 6                         R11            1
# 7                         R12            2
# 8                         R13            3
# 9                         R14            1
# 10                        R15            2
# 11                        R16            3
#
#                                         Seed Strain Batch  \
# 0   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 1   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 2   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 3   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 4   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 5   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 6   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 7   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 8   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 9   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 10  DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 11  DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
#
#     Initial Culture VolumeNone Culture Volume Unit  Temperature Setpoint (C)  \
# 0                          100                  mL                        30
# 1                          100                  mL                        30
# 2                          100                  mL                        30
# 3                          100                  mL                        30
# 4                          100                  mL                        30
# 5                          100                  mL                        30
# 6                          100                  mL                        30
# 7                          100                  mL                        30
# 8                          100                  mL                        30
# 9                          100                  mL                        30
# 10                         100                  mL                        30
# 11                         100                  mL                        30
#
#     pH Setpoint pH Control Base Solution Aeration Gas Type
# 0           6.5    Ammonium hydroxide 8%               Air
# 1           6.5    Ammonium hydroxide 8%               NaN
# 2           6.5    Ammonium hydroxide 8%               NaN
# 3           6.5    Ammonium hydroxide 8%               NaN
# 4           6.5    Ammonium hydroxide 8%               NaN
# 5           6.5    Ammonium hydroxide 8%               NaN
# 6           6.5    Ammonium hydroxide 8%               NaN
# 7           6.5    Ammonium hydroxide 8%               NaN
# 8           6.5    Ammonium hydroxide 8%               NaN
# 9           6.5    Ammonium hydroxide 8%               NaN
# 10          6.5    Ammonium hydroxide 8%               NaN
# 11          6.5    Ammonium hydroxide 8%               NaN

# %%
meta_df_1['Condition'] = ['control','control','control','substrate_scale_down','substrate_scale_down','substrate_scale_down','oxygen_scale_down','oxygen_scale_down','oxygen_scale_down','substrate_and_oxygen_scale_down','substrate_and_oxygen_scale_down','substrate_and_oxygen_scale_down']

# %%
meta_df =pd.concat([meta_df_1]).reset_index().drop('index',axis=1)
meta_df
# Out:
#                          Parent Culture Base Medium Container ID (calculated)  \
# 0   DDB_PD_131_AMBR_DDB35-006_R05_Main_  DDB_BM_016                       R05
# 1   DDB_PD_131_AMBR_DDB35-006_R06_Main_  DDB_BM_016                       R06
# 2   DDB_PD_131_AMBR_DDB35-006_R07_Main_  DDB_BM_016                       R07
# 3   DDB_PD_131_AMBR_DDB35-006_R08_Main_  DDB_BM_016                       R08
# 4   DDB_PD_131_AMBR_DDB35-006_R09_Main_  DDB_BM_016                       R09
# 5   DDB_PD_131_AMBR_DDB35-006_R10_Main_  DDB_BM_016                       R10
# 6   DDB_PD_131_AMBR_DDB35-006_R11_Main_  DDB_BM_016                       R11
# 7   DDB_PD_131_AMBR_DDB35-006_R12_Main_  DDB_BM_016                       R12
# 8   DDB_PD_131_AMBR_DDB35-006_R13_Main_  DDB_BM_016                       R13
# 9   DDB_PD_131_AMBR_DDB35-006_R14_Main_  DDB_BM_016                       R14
# 10  DDB_PD_131_AMBR_DDB35-006_R15_Main_  DDB_BM_016                       R15
# 11  DDB_PD_131_AMBR_DDB35-006_R16_Main_  DDB_BM_016                       R16
#
#    Container Type Control? Culture Type       Experiment Feed Medium #1  \
# 0        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 1        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 2        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 3        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 4        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 5        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 6        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 7        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 8        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 9        AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 10       AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
# 11       AMBR 250       No         Main  DDB_PD_131_AMBR     DDB_FM_016
#
#    Reactor/Plate/Flask Number  Replicate #  \
# 0                         R05            1
# 1                         R06            2
# 2                         R07            3
# 3                         R08            1
# 4                         R09            2
# 5                         R10            3
# 6                         R11            1
# 7                         R12            2
# 8                         R13            3
# 9                         R14            1
# 10                        R15            2
# 11                        R16            3
#
#                                         Seed Strain Batch  \
# 0   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 1   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 2   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 3   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 4   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 5   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 6   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 7   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 8   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 9   DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 10  DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
# 11  DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_    DDB35-006
#
#     Initial Culture VolumeNone Culture Volume Unit  Temperature Setpoint (C)  \
# 0                          100                  mL                        30
# 1                          100                  mL                        30
# 2                          100                  mL                        30
# 3                          100                  mL                        30
# 4                          100                  mL                        30
# 5                          100                  mL                        30
# 6                          100                  mL                        30
# 7                          100                  mL                        30
# 8                          100                  mL                        30
# 9                          100                  mL                        30
# 10                         100                  mL                        30
# 11                         100                  mL                        30
#
#     pH Setpoint pH Control Base Solution Aeration Gas Type  \
# 0           6.5    Ammonium hydroxide 8%               Air
# 1           6.5    Ammonium hydroxide 8%               NaN
# 2           6.5    Ammonium hydroxide 8%               NaN
# 3           6.5    Ammonium hydroxide 8%               NaN
# 4           6.5    Ammonium hydroxide 8%               NaN
# 5           6.5    Ammonium hydroxide 8%               NaN
# 6           6.5    Ammonium hydroxide 8%               NaN
# 7           6.5    Ammonium hydroxide 8%               NaN
# 8           6.5    Ammonium hydroxide 8%               NaN
# 9           6.5    Ammonium hydroxide 8%               NaN
# 10          6.5    Ammonium hydroxide 8%               NaN
# 11          6.5    Ammonium hydroxide 8%               NaN
#
#                           Condition
# 0                           control
# 1                           control
# 2                           control
# 3              substrate_scale_down
# 4              substrate_scale_down
# 5              substrate_scale_down
# 6                 oxygen_scale_down
# 7                 oxygen_scale_down
# 8                 oxygen_scale_down
# 9   substrate_and_oxygen_scale_down
# 10  substrate_and_oxygen_scale_down
# 11  substrate_and_oxygen_scale_down

# %% [markdown]
# ### Load online data

# %%
online_df_1 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_131_AMBR_online_data_export.csv')
# Out:
# C:\Users\jonas\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3526: DtypeWarning: Columns (41) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
online_df = pd.concat([online_df_1])
online_df
# Out:
#            Time         DO        pH  Stirrer_speed  Temperature  Pressure  \
# 0        0.0000  99.543203  6.509665     999.665160    30.002217  0.352778
# 1        0.0025  98.811499  6.511619     998.476214    29.989524  1.304719
# 2        0.0050  98.191227  6.513463     999.343662    29.977312  2.307860
# 3        0.0075  97.722240  6.512000    1002.933198    29.969866  2.686794
# 4        0.0100  97.452985  6.512000     999.217672    29.962434  2.897836
# ...         ...        ...       ...            ...          ...       ...
# 371974  85.0750        NaN  5.734576     501.101921     8.000000  3.576532
# 371975  85.0775        NaN  5.735210     502.210144     8.000000  3.729626
# 371976  85.0800        NaN  5.733052     500.052213     8.000000  3.993613
# 371977  85.0825        NaN  5.733000     500.000000     8.000000  3.836855
# 371978  85.0850        NaN  5.733526     498.947316     8.000000  3.488038
#
#           Air_flow  Oxygen_flow  Inlet_air_O2  Offgas_O2  ...  Replicate #  \
# 0       100.013705          NaN     20.950000  20.689557  ...            1
# 1       100.109567          NaN     20.950000  20.689476  ...            1
# 2       100.142303          NaN     20.950000  20.689805  ...            1
# 3       100.036134          NaN     20.950000  20.691959  ...            1
# 4        99.987830          NaN     20.950000  20.689730  ...            1
# ...            ...          ...           ...        ...  ...          ...
# 371974  100.105826          0.0     20.950000  20.644372  ...            3
# 371975  100.033358          0.0     20.950000  20.640420  ...            3
# 371976   99.971498          0.0     20.950000  20.636104  ...            3
# 371977   99.761663          0.0     20.950000  20.637532  ...            3
# 371978   47.222757          0.0      9.923136  20.634842  ...            3
#
#                                             Seed  Strain Batch  \
# 0       DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_     DDB35-006
# 1       DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_     DDB35-006
# 2       DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_     DDB35-006
# 3       DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_     DDB35-006
# 4       DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_     DDB35-006
# ...                                          ...           ...
# 371974  DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_     DDB35-006
# 371975  DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_     DDB35-006
# 371976  DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_     DDB35-006
# 371977  DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_     DDB35-006
# 371978  DDB_PD_131_AMBR_DDB35-006_R17_Pre-Final_     DDB35-006
#
#         Initial Culture VolumeNone  Culture Volume Unit  \
# 0                              100                   mL
# 1                              100                   mL
# 2                              100                   mL
# 3                              100                   mL
# 4                              100                   mL
# ...                            ...                  ...
# 371974                         100                   mL
# 371975                         100                   mL
# 371976                         100                   mL
# 371977                         100                   mL
# 371978                         100                   mL
#
#         Temperature Setpoint (C)  pH Setpoint  pH Control Base Solution  \
# 0                             30          6.5     Ammonium hydroxide 8%
# 1                             30          6.5     Ammonium hydroxide 8%
# 2                             30          6.5     Ammonium hydroxide 8%
# 3                             30          6.5     Ammonium hydroxide 8%
# 4                             30          6.5     Ammonium hydroxide 8%
# ...                          ...          ...                       ...
# 371974                        30          6.5     Ammonium hydroxide 8%
# 371975                        30          6.5     Ammonium hydroxide 8%
# 371976                        30          6.5     Ammonium hydroxide 8%
# 371977                        30          6.5     Ammonium hydroxide 8%
# 371978                        30          6.5     Ammonium hydroxide 8%
#
#         Aeration Gas Type  Phase
# 0                     Air  batch
# 1                     Air  batch
# 2                     Air  batch
# 3                     Air  batch
# 4                     Air  batch
# ...                   ...    ...
# 371974                NaN   feed
# 371975                NaN   feed
# 371976                NaN   feed
# 371977                NaN   feed
# 371978                NaN   feed
#
# [371979 rows x 43 columns]

# %% [markdown]
# ### Load and edit offline data

# %%
offline_df_1 = pd.read_csv('../../../data/fermentation_data_exports/DDB_PD_131_AMBR_offline_data_export.csv')

# %%
offline_df = pd.concat([offline_df_1]).reset_index().drop('index',axis=1)

# %%
# merge with metadata to filter by when plotting
offline_df = pd.merge(left=offline_df,right=meta_df[['Parent Culture','Strain Batch','Condition']],how='left')

# %%
# finding the last timepoint in batch phase in online data
batch_end_df = online_df[online_df['Phase'] == 'batch'][['Parent Culture','Time']].groupby('Parent Culture').max().reset_index()
batch_end_df.rename(columns={'Time':'batch_end'},inplace=True)
batch_end_df
# Out:
#                          Parent Culture  batch_end
# 0   DDB_PD_131_AMBR_DDB35-006_R05_Main_    14.0200
# 1   DDB_PD_131_AMBR_DDB35-006_R06_Main_    13.9175
# 2   DDB_PD_131_AMBR_DDB35-006_R07_Main_    13.8950
# 3   DDB_PD_131_AMBR_DDB35-006_R08_Main_    14.0050
# 4   DDB_PD_131_AMBR_DDB35-006_R09_Main_    14.1000
# 5   DDB_PD_131_AMBR_DDB35-006_R10_Main_    13.7750
# 6   DDB_PD_131_AMBR_DDB35-006_R11_Main_    14.2125
# 7   DDB_PD_131_AMBR_DDB35-006_R12_Main_    13.9975
# 8   DDB_PD_131_AMBR_DDB35-006_R13_Main_    13.9550
# 9   DDB_PD_131_AMBR_DDB35-006_R14_Main_    14.0200
# 10  DDB_PD_131_AMBR_DDB35-006_R15_Main_    13.9375
# 11  DDB_PD_131_AMBR_DDB35-006_R16_Main_    14.0675

# %%
# merge batch end times into offline data
offline_df = pd.merge(left=offline_df,right=batch_end_df,how='left')
offline_df['feed_time'] = offline_df['Timepoint (h)'] - offline_df['batch_end']

# %%
# avergae timepoints between biological replicates
avergae_timepoint_df = offline_df[['Strain Batch','Timepoint (#)','Condition','Timepoint (h)']].groupby(
    by=['Strain Batch','Timepoint (#)','Condition'],
    as_index=False
).mean()
avergae_timepoint_df.rename(columns={"Timepoint (h)": "Average Timepoint (h)"},inplace=True)
avergae_timepoint_df
# Out:
#    Strain Batch Timepoint (#)                        Condition  \
# 0     DDB35-006          RNA1                          control
# 1     DDB35-006          RNA1                oxygen_scale_down
# 2     DDB35-006          RNA1  substrate_and_oxygen_scale_down
# 3     DDB35-006          RNA1             substrate_scale_down
# 4     DDB35-006          RNA2                oxygen_scale_down
# 5     DDB35-006          RNA2             substrate_scale_down
# 6     DDB35-006           S01                          control
# 7     DDB35-006           S01                oxygen_scale_down
# 8     DDB35-006           S01  substrate_and_oxygen_scale_down
# 9     DDB35-006           S01             substrate_scale_down
# 10    DDB35-006           S02                          control
# 11    DDB35-006           S02                oxygen_scale_down
# 12    DDB35-006           S02  substrate_and_oxygen_scale_down
# 13    DDB35-006           S02             substrate_scale_down
# 14    DDB35-006           S03                          control
# 15    DDB35-006           S03                oxygen_scale_down
# 16    DDB35-006           S03  substrate_and_oxygen_scale_down
# 17    DDB35-006           S03             substrate_scale_down
# 18    DDB35-006           S04                          control
# 19    DDB35-006           S04                oxygen_scale_down
# 20    DDB35-006           S04  substrate_and_oxygen_scale_down
# 21    DDB35-006           S04             substrate_scale_down
# 22    DDB35-006           S05                          control
# 23    DDB35-006           S05                oxygen_scale_down
# 24    DDB35-006           S05  substrate_and_oxygen_scale_down
# 25    DDB35-006           S05             substrate_scale_down
# 26    DDB35-006           S06                          control
# 27    DDB35-006           S06                oxygen_scale_down
# 28    DDB35-006           S06  substrate_and_oxygen_scale_down
# 29    DDB35-006           S06             substrate_scale_down
# 30    DDB35-006           S07                          control
# 31    DDB35-006           S07                oxygen_scale_down
# 32    DDB35-006           S07  substrate_and_oxygen_scale_down
# 33    DDB35-006           S07             substrate_scale_down
# 34    DDB35-006           S08                          control
# 35    DDB35-006           S08                oxygen_scale_down
# 36    DDB35-006           S08  substrate_and_oxygen_scale_down
# 37    DDB35-006           S08             substrate_scale_down
#
#     Average Timepoint (h)
# 0               66.925878
# 1               67.393548
# 2               67.520539
# 3               66.483917
# 4               67.524562
# 5               66.587695
# 6               22.736636
# 7               22.851518
# 8               22.803925
# 9               22.750774
# 10              29.756868
# 11              29.871867
# 12              29.824061
# 13              29.772449
# 14              36.756945
# 15              36.874163
# 16              36.822445
# 17              36.771131
# 18              43.754888
# 19              43.870666
# 20              43.823072
# 21              43.771828
# 22              50.766095
# 23              50.874448
# 24              50.826742
# 25              50.780352
# 26              57.757366
# 27              57.871614
# 28              57.825007
# 29              57.772818
# 30              68.083510
# 31              68.049061
# 32              68.029944
# 33              68.065138
# 34              68.342488
# 35              68.314673
# 36              68.301774
# 37              68.328143

# %%
avergae_timepoint_df['Strain Batch'].unique()
# Out:
# array(['DDB35-006'], dtype=object)

# %%
# merge averaged timepoints into offline data
offline_df = pd.merge(left=offline_df,right=avergae_timepoint_df,how='left')

# %%
# average timepoint from feed start (batch end time subtracted) between biological replicates
avergae_feed_timepoint_df = offline_df[['Strain Batch','Timepoint (#)','Condition','feed_time']].groupby(
    by=['Strain Batch','Timepoint (#)','Condition'],
    as_index=False
).mean()
avergae_feed_timepoint_df.rename(columns={"feed_time": "average_feed_time"},inplace=True)

# %%
# merge averaged timepoints from feed start into offline data
offline_df = pd.merge(left=offline_df,right=avergae_feed_timepoint_df,how='left')

# %%
offline_df
# Out:
#               Timepoint Sample       Experiment  \
# 0     DDB_PD_131_AMBR_R05__S01  DDB_PD_131_AMBR
# 1     DDB_PD_131_AMBR_R05__S02  DDB_PD_131_AMBR
# 2     DDB_PD_131_AMBR_R05__S03  DDB_PD_131_AMBR
# 3     DDB_PD_131_AMBR_R05__S04  DDB_PD_131_AMBR
# 4     DDB_PD_131_AMBR_R05__S05  DDB_PD_131_AMBR
# ..                         ...              ...
# 109   DDB_PD_131_AMBR_R16__S05  DDB_PD_131_AMBR
# 110   DDB_PD_131_AMBR_R16__S06  DDB_PD_131_AMBR
# 111  DDB_PD_131_AMBR_R16__RNA1  DDB_PD_131_AMBR
# 112   DDB_PD_131_AMBR_R16__S07  DDB_PD_131_AMBR
# 113   DDB_PD_131_AMBR_R16__S08  DDB_PD_131_AMBR
#
#                           Parent Culture Reactor/Plate/Flask Number  \
# 0    DDB_PD_131_AMBR_DDB35-006_R05_Main_                        R05
# 1    DDB_PD_131_AMBR_DDB35-006_R05_Main_                        R05
# 2    DDB_PD_131_AMBR_DDB35-006_R05_Main_                        R05
# 3    DDB_PD_131_AMBR_DDB35-006_R05_Main_                        R05
# 4    DDB_PD_131_AMBR_DDB35-006_R05_Main_                        R05
# ..                                   ...                        ...
# 109  DDB_PD_131_AMBR_DDB35-006_R16_Main_                        R16
# 110  DDB_PD_131_AMBR_DDB35-006_R16_Main_                        R16
# 111  DDB_PD_131_AMBR_DDB35-006_R16_Main_                        R16
# 112  DDB_PD_131_AMBR_DDB35-006_R16_Main_                        R16
# 113  DDB_PD_131_AMBR_DDB35-006_R16_Main_                        R16
#
#     Timepoint (#)  Timepoint (h)  Sample volume (mL)      OD  D-glucose [g/L]  \
# 0             S01      22.806129                 1.0   75.28              0.0
# 1             S02      29.826324                 1.5  109.30              0.0
# 2             S03      36.825055                 1.5  152.70              0.0
# 3             S04      43.824616                 1.5  178.40              0.0
# 4             S05      50.825850                 1.5  212.00              0.0
# ..            ...            ...                 ...     ...              ...
# 109           S05      50.873433                 1.5  145.10              0.0
# 110           S06      57.874281                 1.5  139.70              0.0
# 111          RNA1      67.571791                 0.5     NaN              NaN
# 112           S07      68.023281                 1.5  139.80              0.0
# 113           S08      68.297766                 5.5  158.50              NaN
#
#      acetic acid [g/L]  ...  lactate [g/L]  \
# 0             0.242199  ...       0.000000
# 1             0.336886  ...       0.128030
# 2             0.378179  ...       0.183025
# 3             0.385366  ...       0.193833
# 4             0.374385  ...       0.205275
# ..                 ...  ...            ...
# 109           3.198463  ...       0.073336
# 110           5.560938  ...       0.018416
# 111                NaN  ...            NaN
# 112          14.020689  ...       0.000000
# 113                NaN  ...            NaN
#
#      potassium dihydrogen phosphate [g/L]  pyruvic acid [g/L]  \
# 0                               11.213361            0.000000
# 1                                9.585860            0.000000
# 2                                8.430797            0.000000
# 3                                7.130182            0.000000
# 4                                6.336829            0.000000
# ..                                    ...                 ...
# 109                              8.191147            0.000000
# 110                              7.276463            0.000000
# 111                                   NaN                 NaN
# 112                              6.679920            0.018812
# 113                                   NaN                 NaN
#
#      succinic acid [g/L]  Strain Batch                        Condition  \
# 0               0.517768     DDB35-006                          control
# 1               0.792404     DDB35-006                          control
# 2               0.862637     DDB35-006                          control
# 3               0.873692     DDB35-006                          control
# 4               0.824173     DDB35-006                          control
# ..                   ...           ...                              ...
# 109             0.885615     DDB35-006  substrate_and_oxygen_scale_down
# 110             0.617671     DDB35-006  substrate_and_oxygen_scale_down
# 111                  NaN     DDB35-006  substrate_and_oxygen_scale_down
# 112             0.161393     DDB35-006  substrate_and_oxygen_scale_down
# 113                  NaN     DDB35-006  substrate_and_oxygen_scale_down
#
#      batch_end  feed_time Average Timepoint (h)  average_feed_time
# 0      14.0200   8.786129             22.736636           8.792469
# 1      14.0200  15.806324             29.756868          15.812701
# 2      14.0200  22.805055             36.756945          22.812778
# 3      14.0200  29.804616             43.754888          29.810722
# 4      14.0200  36.805850             50.766095          36.821928
# ..         ...        ...                   ...                ...
# 109    14.0675  36.805933             50.826742          36.818409
# 110    14.0675  43.806781             57.825007          43.816674
# 111    14.0675  53.504291             67.520539          53.512205
# 112    14.0675  53.955781             68.029944          54.021611
# 113    14.0675  54.230266             68.301774          54.293440
#
# [114 rows x 23 columns]

# %% [markdown]
# # ATTENTION

# %%
offline_df['CDW_from_OD_avg [g/L]'] = offline_df['OD']*0.28

# %% [markdown]
# ### Edit online data

# %% [markdown]
# #### Subtracting batch end time

# %%
# merge with metadata to filter by when plotting
online_df = pd.merge(left=online_df,right=meta_df[['Parent Culture','Strain Batch','Condition']],how='left')
# need to fill nan feed volumes with 0 in online data
online_df['Feed_volume'] = online_df['Feed_volume'].fillna(0)

# %%
online_df['Condition'].unique()
# Out:
# array(['control', 'substrate_scale_down', 'oxygen_scale_down',
#        'substrate_and_oxygen_scale_down'], dtype=object)

# %%
# finding the last timepoint in batch phase in online data
batch_end_df = online_df[online_df['Phase'] == 'batch'][['Parent Culture','Time']].groupby('Parent Culture').max().reset_index()
batch_end_df.rename(columns={'Time':'batch_end'},inplace=True)
batch_end_df
# Out:
#                          Parent Culture  batch_end
# 0   DDB_PD_131_AMBR_DDB35-006_R05_Main_    14.0200
# 1   DDB_PD_131_AMBR_DDB35-006_R06_Main_    13.9175
# 2   DDB_PD_131_AMBR_DDB35-006_R07_Main_    13.8950
# 3   DDB_PD_131_AMBR_DDB35-006_R08_Main_    14.0050
# 4   DDB_PD_131_AMBR_DDB35-006_R09_Main_    14.1000
# 5   DDB_PD_131_AMBR_DDB35-006_R10_Main_    13.7750
# 6   DDB_PD_131_AMBR_DDB35-006_R11_Main_    14.2125
# 7   DDB_PD_131_AMBR_DDB35-006_R12_Main_    13.9975
# 8   DDB_PD_131_AMBR_DDB35-006_R13_Main_    13.9550
# 9   DDB_PD_131_AMBR_DDB35-006_R14_Main_    14.0200
# 10  DDB_PD_131_AMBR_DDB35-006_R15_Main_    13.9375
# 11  DDB_PD_131_AMBR_DDB35-006_R16_Main_    14.0675

# %%
# merge batch end times into online data
online_df = pd.merge(left=online_df,right=batch_end_df,how='left')
online_df['feed_time'] = online_df['Time'] - online_df['batch_end']

# %%
# round values
online_df['feed_time'] = np.round(online_df['feed_time'].values,4)

# %% [markdown]
# ### Mol and Cmol conversions

# %% [markdown]
# #### Functions

# %%
def mass_to_mol(new_mol_col,mass_col,compound_mol_mass):
    offline_df[new_mol_col] = offline_df[mass_col]/compound_mol_mass

def mol_to_cmol(new_cmol_col,mol_col,n_c):
    offline_df[new_cmol_col] = offline_df[mol_col]*n_c

# %% [markdown]
# #### Biomass

# %%
new_mol_col = 'CDW_avg_molar'
mass_col = 'CDW_from_OD_avg [g/L]'
compound_mol_mass = 24.6
new_cmol_col = 'CDW_avg_cmolar'
mol_col = new_mol_col
n_c = 1

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Glucose

# %%
new_mol_col = 'glucose_molar'
mass_col = 'D-glucose [g/L]'
compound_mol_mass = 180.156
new_cmol_col = 'glucose_cmolar'
mol_col = new_mol_col
n_c = 6

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Acetate

# %%
new_mol_col = 'acetic_acid_molar'
mass_col = 'acetic acid [g/L]'
compound_mol_mass = 60.052 
new_cmol_col = 'acetic_acid_cmolar'
mol_col = new_mol_col
n_c = 2

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Citrate

# %%
new_mol_col = 'citric_acid_molar'
mass_col = 'citric acid [g/L]'
compound_mol_mass = 192.124
new_cmol_col = 'citric_acid_cmolar'
mol_col = new_mol_col
n_c = 6

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Ethanol

# %%
new_mol_col = 'ethanol_molar'
mass_col = 'ethanol [g/L]'
compound_mol_mass = 46.07
new_cmol_col = 'ethanol_cmolar'
mol_col = new_mol_col
n_c = 2

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Formate

# %%
new_mol_col = 'formic_acid_molar'
mass_col = 'formic acid [g/L]'
compound_mol_mass = 46.03
new_cmol_col = 'formic_acid_cmolar'
mol_col = new_mol_col
n_c = 1

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Lactate

# %%
new_mol_col = 'lactate_molar'
mass_col = 'lactate [g/L]'
compound_mol_mass = 90.08
new_cmol_col = 'lactate_cmolar'
mol_col = new_mol_col
n_c = 3

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Pyruvate

# %%
new_mol_col = 'pyruvic_acid_molar'
mass_col = 'pyruvic acid [g/L]'
compound_mol_mass = 88.06
new_cmol_col = 'pyruvic_acid_cmolar'
mol_col = new_mol_col
n_c = 3

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# #### Succinate

# %%
new_mol_col = 'succinic_acid_molar'
mass_col = 'succinic acid [g/L]'
compound_mol_mass = 118.09
new_cmol_col = 'succinic_acid_cmolar'
mol_col = new_mol_col
n_c = 4

mass_to_mol(new_mol_col,mass_col,compound_mol_mass)
mol_to_cmol(new_cmol_col,mol_col,n_c)

# %% [markdown]
# ### Advanced calculations

# %% [markdown]
# #### Functions

# %%
def lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col):
    offline_df[new_lost_col] = offline_df[measurement_col] * offline_df['Sample volume (mL)']/1000
    offline_df[new_lost_cumsum_col] = offline_df.groupby(['Parent Culture']).cumsum()[new_lost_col]
    offline_df[new_lost_cumsum_col] = offline_df.groupby('Parent Culture').shift()[new_lost_cumsum_col].fillna(0)
    
def net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount):
    # Formed amount = residual_conc*volume + lost_amount - initial_amount - feed_conc*feed_vol
    offline_df[new_net_col] = offline_df[residual_col]*offline_df['Liquid_volume']/1000 + offline_df[lost_cumsum_col] - init_amount - feed_conc*offline_df['Feed_volume']/1000
    
def net_consumption(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount):
    # Formed amount = residual_conc*volume + lost_amount - initial_amount - feed_conc*feed_vol
    offline_df[new_net_col] = -offline_df[residual_col]*offline_df['Liquid_volume']/1000 - offline_df[lost_cumsum_col] + init_amount + feed_conc*offline_df['Feed_volume']/1000

# %% [markdown]
# #### Lost masses (due to sampling) calculations

# %% [markdown]
# ##### Lost biomass (cmol)

# %%
new_lost_col = 'lost_biomass_cmol'
new_lost_cumsum_col = 'lost_biomass_cumsum_cmol'
measurement_col = 'CDW_avg_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost biomass (g)

# %%
new_lost_col = 'lost_biomass_g'
new_lost_cumsum_col = 'lost_biomass_cumsum_g'
measurement_col = 'CDW_from_OD_avg [g/L]'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost glucose (cmol)

# %%
new_lost_col = 'lost_glucose_cmol'
new_lost_cumsum_col = 'lost_glucose_cumsum_cmol'
measurement_col = 'glucose_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost glucose (g)

# %%
new_lost_col = 'lost_glucose_g'
new_lost_cumsum_col = 'lost_glucose_cumsum_g'
measurement_col = 'D-glucose [g/L]'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost acetate (cmol)

# %%
new_lost_col = 'lost_acetic_acid_cmol'
new_lost_cumsum_col = 'lost_acetic_acid_cumsum_cmol'
measurement_col = 'acetic_acid_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost citrate (cmol)

# %%
new_lost_col = 'lost_citric_acid_cmol'
new_lost_cumsum_col = 'lost_citric_acid_cumsum_cmol'
measurement_col = 'citric_acid_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost ethanol (cmol)

# %%
new_lost_col = 'lost_ethanol_cmol'
new_lost_cumsum_col = 'lost_ethanol_cumsum_cmol'
measurement_col = 'ethanol_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost formate (cmol)

# %%
new_lost_col = 'lost_formic_acid_cmol'
new_lost_cumsum_col = 'lost_formic_acid_cumsum_cmol'
measurement_col = 'formic_acid_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost lactate (cmol)

# %%
new_lost_col = 'lost_lactate_cmol'
new_lost_cumsum_col = 'lost_lactate_cumsum_cmol'
measurement_col = 'lactate_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost pyruvate (cmol)

# %%
new_lost_col = 'lost_pyruvic_acid_cmol'
new_lost_cumsum_col = 'lost_pyruvic_acid_cumsum_cmol'
measurement_col = 'pyruvic_acid_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# ##### Lost succinate (cmol)

# %%
new_lost_col = 'lost_succinic_acid_cmol'
new_lost_cumsum_col = 'lost_succinic_acid_cumsum_cmol'
measurement_col = 'succinic_acid_cmolar'

lost_compount_calc(new_lost_col,new_lost_cumsum_col,measurement_col)

# %% [markdown]
# #### Liquid and feeding volume from online data into offline data

# %%
# slicing offline dataframe
slice_offline_df = offline_df[['Parent Culture','Timepoint (h)','Timepoint (#)']].rename(columns={'Timepoint (h)':'Time'})
# concat online with sliced dataframe
df = pd.concat([online_df,slice_offline_df])
# sorting dataframe by parent culture and time
df.sort_values(['Parent Culture','Time'],inplace=True)
# filling nan values in liquid volume column from offline data rows with the previous liquid volume value from the online data 
df['Liquid_volume'] = df['Liquid_volume'].fillna(method='ffill')
df['Feed_volume'] = df['Feed_volume'].fillna(method='ffill')
# taking only the rows that have a sample timepoint (#), i.e. the offline samples
df.dropna(subset=['Timepoint (#)'], inplace=True)
#merging subset of sf with offline data
df = df[['Parent Culture','Timepoint (#)','Liquid_volume','Feed_volume']]
offline_df = pd.concat([offline_df,df[['Liquid_volume','Feed_volume']]],axis=1)

# %% [markdown]
# #### Net compound formation/consumption

# %% [markdown]
# ##### Net biomass (cmol)

# %%
lost_cumsum_col = 'lost_biomass_cumsum_cmol'
residual_col = 'CDW_avg_cmolar'
new_net_col = 'net_biomass_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net biomass (g)

# %%
lost_cumsum_col = 'lost_biomass_cumsum_g'
residual_col = 'CDW_from_OD_avg [g/L]'
new_net_col = 'net_biomass_g'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net glucose (cmol)

# %%
lost_cumsum_col = 'lost_glucose_cumsum_cmol'
residual_col = 'glucose_cmolar'
new_net_col = 'net_glucose_cmol'
feed_conc = 500/180.156*6
init_amount = 2/180.156*6

net_consumption(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net glucose (g)

# %%
lost_cumsum_col = 'lost_glucose_cumsum_g'
residual_col = 'D-glucose [g/L]'
new_net_col = 'net_glucose_g'
feed_conc = 500
init_amount = 2

net_consumption(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net acetate (cmol)

# %%
lost_cumsum_col = 'lost_acetic_acid_cumsum_cmol'
residual_col = 'acetic_acid_cmolar'
new_net_col = 'net_acetic_acid_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net citrate (cmol)

# %%
lost_cumsum_col = 'lost_citric_acid_cumsum_cmol'
residual_col = 'citric_acid_cmolar'
new_net_col = 'net_citric_acid_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net ethanol (cmol)

# %%
lost_cumsum_col = 'lost_ethanol_cumsum_cmol'
residual_col = 'ethanol_cmolar'
new_net_col = 'net_ethanol_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net formate (cmol)

# %%
lost_cumsum_col = 'lost_formic_acid_cumsum_cmol'
residual_col = 'formic_acid_cmolar'
new_net_col = 'net_formic_acid_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net lactate (cmol)

# %%
lost_cumsum_col = 'lost_lactate_cumsum_cmol'
residual_col = 'lactate_cmolar'
new_net_col = 'net_lactate_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net pyruvate (cmol)

# %%
lost_cumsum_col = 'lost_pyruvic_acid_cumsum_cmol'
residual_col = 'pyruvic_acid_cmolar'
new_net_col = 'net_pyruvic_acid_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# ##### Net succinate (cmol)

# %%
lost_cumsum_col = 'lost_succinic_acid_cumsum_cmol'
residual_col = 'succinic_acid_cmolar'
new_net_col = 'net_succinic_acid_cmol'
feed_conc = 0
init_amount = 0

net_formation(lost_cumsum_col, residual_col, new_net_col, feed_conc, init_amount)

# %% [markdown]
# #### CTR_int, Base volume, and OTR_int from online data into offline data

# %%
# slicing offline dataframe
slice_offline_df = offline_df[['Parent Culture','Timepoint (h)','Timepoint (#)']].rename(columns={'Timepoint (h)':'Time'})
df = pd.concat([online_df,slice_offline_df])
# sorting dataframe by parent culture and time
df.sort_values(['Parent Culture','Time'],inplace=True)
# filling nan values with previous value
df['Formed_CO2'] = df['Formed_CO2'].fillna(method='ffill')
df['Consumed_O2'] = df['Consumed_O2'].fillna(method='ffill')
df['Base_volume'] = df['Base_volume'].fillna(method='ffill')
# taking only the rows that have a sample timepoint (#), i.e. the offline samples
df.dropna(subset=['Timepoint (#)'], inplace=True)
#merging subset of sf with offline data
df = df[['Parent Culture','Timepoint (#)','Formed_CO2','Consumed_O2','Base_volume']]
offline_df = pd.concat([offline_df,df[['Formed_CO2','Consumed_O2','Base_volume']]],axis=1)

# %% [markdown]
# ## Export data

# %%
online_df.to_excel('../../../data/processed_fermentation_data/oxygen_scale-down_online_data.xlsx',index=False)
# online_df.iloc[::5].to_excel('../../../data/processed_fermentation_data/exponential_fed-batch_scale-down_online_data.xlsx',index=False)

# %%
offline_df.to_excel('../../../data/processed_fermentation_data/oxygen_scale-down_offline_data.xlsx',index=False)
